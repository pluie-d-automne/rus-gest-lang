# %%
from utils import VideoDataset, validate_model, train_model, display_frames, display_learning_dynamic, classification_model_metrics
import torch
import pandas as pd
# Out:
# 2024-01-21 09:35:33.590272: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-21 09:35:34.725922: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-21 09:35:37.900551: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
annotations_file = "/home/jupyter/mnt/s3/rsl-videos/slovo/slovo_annotations/SLOVO_DATAFRAME.tsv"
video_labels = pd.read_csv(annotations_file, sep='\t')
classes = tuple(video_labels.text.unique())

# %%
x_dataloader = torch.load('/home/jupyter/mnt/s3/rsl-videos/slovo/color_frames_test_dataloader.pth')

# %%
print(len(x_dataloader))
# Out:
# 2000

# %%
display_frames(n_frames=1, dataloader=x_dataloader, classes=classes)

# %%
y_dataloader = torch.load('/home/jupyter/mnt/s3/rsl-videos/slovo/color_frames_val_dataloader.pth')

# %%
print(len(y_dataloader))
# Out:
# 2000

# %%
display_frames(n_frames=1, dataloader=y_dataloader, classes=classes)

# %%
z_dataloader = torch.load('/home/jupyter/mnt/s3/rsl-videos/slovo/color_frames_train_dataloader.pth')
# Execution started at 2024-01-21 12:35:52
# Last executed at 2024-01-21 12:44:55 in 9m 2.60s

# %%
print(len(z_dataloader))
# Out:
# 16000

# %%
display_frames(n_frames=1, dataloader=z_dataloader, classes=classes)
