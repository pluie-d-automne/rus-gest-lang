# %% [markdown]
# # EDA: Slovo

# %%
dataset_path = 'C:/Users/pdkud/Downloads/Slovo'

# %%
import os
import pandas as pd

# %%
os.listdir(dataset_path)
# Out:
# ['annotations.csv']

# %%
annot_df = pd.read_csv(dataset_path+'/annotations.csv', sep='\t')

# %%
set(annot_df.text)
# Out:
# {'смущенный',
#  'весенняя',
#  'гений',
#  'больше',
#  'миленький',
#  'смелость',
#  'смешной',
#  'два',
#  'жизнь',
#  'весь',
#  'рычание',
#  'самоосознание',
#  'золотой',
#  'фиолетовый',
#  'пингвин',
#  'обучать',
#  'следующий',
#  'расстроенный',
#  'помесь',
#  'откладывать',
#  'трусливо',
#  'желать',
#  'новости',
#  'я',
#  'грубый',
#  'Щ',
#  'охотно',
#  'жадность',
#  'зелёный',
#  'меня',
#  'лечь',
#  'изношенный',
#  'плохой',
#  'лев',
#  'любить',
#  'сегодня',
#  'подруга',
#  'осел',
#  'тёплый',
#  'рыба',
#  'коготь',
#  'дрожать',
#  'Религия',
#  'слушать',
#  'Лицо',
#  'нуждаться',
#  'внизу',
#  'аккуратный',
#  'истерик',
#  'полный',
#  'жестокий',
#  'жёсткий',
#  'пока (что)',
#  'следовало',
#  'краткий',
#  'облегчение',
#  'невиновный',
#  'билет',
#  'язык',
#  'там',
#  'одинокий',
#  'ревнивый',
#  'глотать жадно',
#  'три тысячи',
#  'использовать',
#  'народ',
#  'радость',
#  'назад',
#  'сердце',
#  'жадный',
#  'смириться',
# ...

# %%
len(annot_df.attachment_id.unique())
# Out:
# 20400
